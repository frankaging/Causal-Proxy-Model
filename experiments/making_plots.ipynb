# %% [markdown]
# ### Pretty Random Plot Drawer

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# ablation effects: interchange point, interchange site size

# %%
l2_layer = [0.6934, 0.6622, 0.6013, 0.5702, 0.5774]
l2_size = [0.6661, 0.6524, 0.6448, 0.6175, 0.6141, 0.595, 0.5807]

cosine_layer = [0.4818, 0.4661, 0.44, 0.4224, 0.4271]
cosine_size = [0.4757, 0.467, 0.4629, 0.4447, 0.4514, 0.4403, 0.4279]

normdiff_layer = [0.5938, 0.5505, 0.4612, 0.4221, 0.4423]
normdiff_size = [0.555, 0.5289, 0.518, 0.4924, 0.4845, 0.4518, 0.4434]

f1_layer = [0.636622, 0.628947, 0.659282, 0.695066, 0.695535]
f1_size = [0.643725, 0.651476, 0.658526, 0.655617, 0.67949, 0.691322, 0.698382]

x_layer = [2, 4, 8, 10, 12]
x_size = [1, 4, 16, 32, 64, 128, 192]

# %%
plt.rcParams["font.family"] = "DejaVu Serif"
font = {'family' : 'DejaVu Serif',
        'size'   : 20}
plt.rc('font', **font)
with plt.rc_context({
    'axes.edgecolor':'black', 'xtick.color':'black', 
    'ytick.color':'black', 'axes.facecolor':'white', 
}):
    fig, axs = plt.subplots(2, 4, figsize=(18, 5))

    axs[0,0].set_title(r'L2$_{\rm ICaCE}$', fontsize=20)
    axs[0,0].errorbar(x_layer, l2_layer, linewidth=2,
                       color="dodgerblue", marker="*", markersize=18, 
                       capsize=2, capthick=1, ecolor='g')
    axs[0,0].spines['right'].set_visible(False)
    axs[0,0].spines['top'].set_visible(False)
    axs[0,0].spines['left'].set_linewidth(3)
    axs[0,0].spines['bottom'].set_linewidth(3)
    axs[0,0].xaxis.set_tick_params(labelsize=15)
    axs[0,0].yaxis.set_tick_params(labelsize=15)

    axs[0,1].set_title(r'COS$_{\rm ICaCE}$', fontsize=20)
    axs[0,1].errorbar(x_layer, cosine_layer, linewidth=2,
                       color="dodgerblue", marker="*", markersize=18, 
                       capsize=2, capthick=1, ecolor='g')
    axs[0,1].spines['right'].set_visible(False)
    axs[0,1].spines['top'].set_visible(False)
    axs[0,1].spines['left'].set_linewidth(3)
    axs[0,1].spines['bottom'].set_linewidth(3)
    axs[0,1].xaxis.set_tick_params(labelsize=15)
    axs[0,1].yaxis.set_tick_params(labelsize=15)
    
    axs[0,2].set_title(r'NormDiff$_{\rm ICaCE}$', fontsize=20)
    axs[0,2].errorbar(x_layer, normdiff_layer, linewidth=2,
                       color="dodgerblue", marker="*", markersize=18, 
                       capsize=2, capthick=1, ecolor='g')
    axs[0,2].spines['right'].set_visible(False)
    axs[0,2].spines['top'].set_visible(False)
    axs[0,2].spines['left'].set_linewidth(3)
    axs[0,2].spines['bottom'].set_linewidth(3)
    axs[0,2].xaxis.set_tick_params(labelsize=15)
    axs[0,2].yaxis.set_tick_params(labelsize=15)
    
    axs[0,3].set_title(r'Macro-F1', fontsize=20)
    axs[0,3].errorbar(x_layer, f1_layer, linewidth=2,
                       color="dodgerblue", marker="*", markersize=18, 
                       capsize=2, capthick=1, ecolor='g')
    axs[0,3].spines['right'].set_visible(False)
    axs[0,3].spines['top'].set_visible(False)
    axs[0,3].spines['left'].set_linewidth(3)
    axs[0,3].spines['bottom'].set_linewidth(3)
    axs[0,3].xaxis.set_tick_params(labelsize=15)
    axs[0,3].yaxis.set_tick_params(labelsize=15)
    
    fig.text(0.5, 0.48, 'Intervention Site Location', va='center', ha='center', fontsize=18)
    
    axs[1,0].errorbar(x_size, l2_size, linewidth=2,
                       color="red", marker="^", markersize=18, 
                       capsize=2, capthick=1, ecolor='g')
    axs[1,0].spines['right'].set_visible(False)
    axs[1,0].spines['top'].set_visible(False)
    axs[1,0].spines['left'].set_linewidth(3)
    axs[1,0].spines['bottom'].set_linewidth(3)
    axs[1,0].xaxis.set_tick_params(labelsize=15)
    axs[1,0].yaxis.set_tick_params(labelsize=15)

    axs[1,1].errorbar(x_size, cosine_size, linewidth=2,
                       color="red", marker="^", markersize=18, 
                       capsize=2, capthick=1, ecolor='g')
    axs[1,1].spines['right'].set_visible(False)
    axs[1,1].spines['top'].set_visible(False)
    axs[1,1].spines['left'].set_linewidth(3)
    axs[1,1].spines['bottom'].set_linewidth(3)
    axs[1,1].xaxis.set_tick_params(labelsize=15)
    axs[1,1].yaxis.set_tick_params(labelsize=15)
    
    axs[1,2].errorbar(x_size, normdiff_size, linewidth=2,
                       color="red", marker="^", markersize=18, 
                       capsize=2, capthick=1, ecolor='g')
    axs[1,2].spines['right'].set_visible(False)
    axs[1,2].spines['top'].set_visible(False)
    axs[1,2].spines['left'].set_linewidth(3)
    axs[1,2].spines['bottom'].set_linewidth(3)
    axs[1,2].xaxis.set_tick_params(labelsize=15)
    axs[1,2].yaxis.set_tick_params(labelsize=15)
    
    axs[1,3].errorbar(x_size, f1_size, linewidth=2,
                       color="red", marker="^", markersize=18, 
                       capsize=2, capthick=1, ecolor='g')
    axs[1,3].spines['right'].set_visible(False)
    axs[1,3].spines['top'].set_visible(False)
    axs[1,3].spines['left'].set_linewidth(3)
    axs[1,3].spines['bottom'].set_linewidth(3)
    axs[1,3].xaxis.set_tick_params(labelsize=15)
#     axs[1,3].yaxis.set_tick_params(labelsize=15)
    fig.text(0.5, 0.02, 'Intervention Site Size', va='center', ha='center', fontsize=18)

    plt.subplots_adjust(wspace=0.5, 
                        hspace=0.5)
    
    plt.savefig("./figures/site-and-size-experiments.png",dpi=200, bbox_inches='tight')

# %% [markdown]
# good few-shots true counterfactual plots

# %%
l2_few_shots = [0.7815, 0.6702, 0.6117, 0.5926, 0.5773, 0.5792]
l2_few_shots_aug = [0.6128, 0.6096, 0.6008, 0.5912, 0.5812, 0.5739]
l2_few_shots_aug_balance = [0.7089, 0.6210, 0.6009, 0.5933, 0.5814, 0.5796]
l2_few_shots_aug_large_epochs = [0.6071, 0.5842, 0.5444, 0.5066, 0.5001, 0.4921]
l2_approximate_large_epochs = [0.6486, 0.6298, 0.6173, 0.6166, 0.6196, 0.6229]

cosine_few_shots = [0.5094, 0.4719, 0.4401, 0.4428, 0.4208, 0.4246]
cosine_few_shots_aug = [0.4410, 0.4433, 0.4442, 0.4301, 0.4360, 0.4256]
cosine_few_shots_aug_balance = [0.4853, 0.4377, 0.4380, 0.4277, 0.4252, 0.4300]
cosine_few_shots_aug_large_epochs = [0.4414, 0.4192, 0.4093, 0.3913, 0.385, 0.3903]
cosine_approximate_large_epochs = [0.4655, 0.4551, 0.4482, 0.4508, 0.447, 0.4478]

normdiff_few_shots = [0.4821, 0.4547, 0.4369, 0.4347, 0.4410, 0.4455]
normdiff_few_shots_aug = [0.4697, 0.4627, 0.4626, 0.4449, 0.4389, 0.4380]
normdiff_few_shots_aug_balance = [0.4428, 0.4545, 0.4546, 0.4444, 0.4408, 0.4427]
normdiff_few_shots_aug_large_epochs = [0.4658, 0.437, 0.389, 0.3368, 0.3169, 0.307]
normdiff_approximate_large_epochs = [0.4507, 0.4277, 0.4164, 0.4006, 0.3947, 0.397]

f1_few_shots = [0.321893, 0.584817, 0.663775, 0.676363, 0.682210, 0.695535]
f1_few_shots_aug = [0.693231, 0.699503, 0.684009, 0.696565, 0.680863, 0.702021]
f1_few_shots_aug_balance = [0.443762, 0.655055, 0.694204, 0.701574, 0.685341, 0.699121]
f1_few_shots_aug_large_epochs = [0.695161, 0.700121, 0.702815, 0.707224, 0.708701, 0.702437]
f1_approximate_large_epochs = [0.679037, 0.685264, 0.696032, 0.69145, 0.682125, 0.680482]

k = [5, 50, 200, 600, 1200, 1755]

# %%
plt.rcParams["font.family"] = "DejaVu Serif"
font = {'family' : 'DejaVu Serif',
        'size'   : 20}
plt.rc('font', **font)
with plt.rc_context({
    'axes.edgecolor':'black', 'xtick.color':'black', 
    'ytick.color':'black', 'axes.facecolor':'white', 
}):
    fig, axs = plt.subplots(1, 4, figsize=(18, 5))
    x = k
    
    axs[0].set_title(r'L2$_{\rm ICaCE}$', fontsize=20)
#     axs[0].errorbar(x, l2_few_shots, linewidth=2,
#                        color="dodgerblue", marker="*", markersize=18, 
#                        capsize=2, capthick=1, ecolor='g', label='fewshots')
#     axs[0].errorbar(x, l2_few_shots_aug, linewidth=2,
#                        color="red", marker="^", markersize=18, 
#                        capsize=2, capthick=1, ecolor='r', label='augment')
#     axs[0].errorbar(x, l2_few_shots_aug_balance, linewidth=2,
#                        color="green", marker=".", markersize=18, 
#                        capsize=2, capthick=1, ecolor='y', label='balance')
    axs[0].errorbar(x, l2_few_shots_aug_large_epochs, linewidth=2,
                       color="dodgerblue", marker="*", markersize=18, 
                       capsize=2, capthick=1, ecolor='y', label='CPM')
    axs[0].errorbar(x, l2_approximate_large_epochs, linewidth=2,
                       color="red", ls='-.', marker="^", markersize=18, 
                       capsize=2, capthick=1, ecolor='y', label=r"CPM$_{\rm AC}$")
    # axs[0].set_ylim(0.6, 0.85)
    axs[0].spines['right'].set_visible(False)
    axs[0].spines['top'].set_visible(False)
    axs[0].spines['left'].set_linewidth(3)
    axs[0].spines['bottom'].set_linewidth(3)
    orig_xlim = (axs[0].get_xlim()[0], axs[0].get_xlim()[-1])
    axs[0].plot([axs[0].get_xlim()[0], axs[0].get_xlim()[-1]], 
                [0.74, 0.74], '--', color="grey", linewidth=2, label=r"CEBaB$_{\rm BEST}$")
    axs[0].legend(loc='upper center', bbox_to_anchor=(2.5, 1.3),
                 ncol=6, fancybox=True, shadow=True, fontsize=18, facecolor="white")
    
    axs[0].xaxis.set_tick_params(labelsize=15)
    axs[0].yaxis.set_tick_params(labelsize=15)
    axs[0].set_xlim(orig_xlim[0], orig_xlim[1])
    axs[0].set_ylim(0.30, 0.80)

    axs[1].set_title(r'COS$_{\rm ICaCE}$', fontsize=20)
#     axs[1].errorbar(x, cosine_few_shots, linewidth=2,
#                        color="dodgerblue", marker="*", markersize=18, 
#                        capsize=2, capthick=1, ecolor='g')
#     axs[1].errorbar(x, cosine_few_shots_aug, linewidth=2,
#                        color="red", marker="^", markersize=18, 
#                        capsize=2, capthick=1, ecolor='r')
#     axs[1].errorbar(x, cosine_few_shots_aug_balance, linewidth=2,
#                        color="green", marker=".", markersize=18, 
#                        capsize=2, capthick=1, ecolor='y',)
    axs[1].errorbar(x, cosine_few_shots_aug_large_epochs, linewidth=2,
                       color="dodgerblue", marker="*", markersize=18, 
                       capsize=2, capthick=1, ecolor='y')
    axs[1].errorbar(x, cosine_approximate_large_epochs, linewidth=2,
                       color="red", ls='-.', marker="^", markersize=18, 
                       capsize=2, capthick=1, ecolor='y')
    axs[1].plot([axs[0].get_xlim()[0], axs[0].get_xlim()[-1]], [0.59, 0.59], '--', color="grey", linewidth=2)
    # axs[1].set_ylim(0.4, 0.98)
    axs[1].set_xlim(orig_xlim[0], orig_xlim[1])
    axs[1].set_ylim(0.30, 0.80)
    
    axs[1].spines['right'].set_visible(False)
    axs[1].spines['top'].set_visible(False)
    axs[1].spines['left'].set_linewidth(3)
    axs[1].spines['bottom'].set_linewidth(3)
    axs[1].xaxis.set_tick_params(labelsize=15)
    axs[1].yaxis.set_tick_params(labelsize=15)
    
    
    axs[2].set_title(r'NormDiff$_{\rm ICaCE}$', fontsize=20)
#     axs[2].errorbar(x, normdiff_few_shots, linewidth=2,
#                        color="dodgerblue", marker="*", markersize=18, 
#                        capsize=2, capthick=1, ecolor='g')
#     axs[2].errorbar(x, normdiff_few_shots_aug, linewidth=2,
#                        color="red", marker="^", markersize=18, 
#                        capsize=2, capthick=1, ecolor='r')
#     axs[2].errorbar(x, normdiff_few_shots_aug_balance, linewidth=2,
#                        color="green", marker=".", markersize=18, 
#                        capsize=2, capthick=1, ecolor='y',)
    axs[2].errorbar(x, normdiff_few_shots_aug_large_epochs, linewidth=2,
                       color="dodgerblue", marker="*", markersize=18, 
                       capsize=2, capthick=1, ecolor='y')
    axs[2].errorbar(x, normdiff_approximate_large_epochs, linewidth=2,
                       color="red", ls='-.', marker="^", markersize=18, 
                       capsize=2, capthick=1, ecolor='y')
    axs[2].plot([axs[0].get_xlim()[0], axs[0].get_xlim()[-1]], [0.54, 0.54], '--', color="grey", linewidth=2)
    axs[2].set_xlim(orig_xlim[0], orig_xlim[1])
    axs[2].set_ylim(0.30, 0.80)
    
    axs[2].spines['right'].set_visible(False)
    axs[2].spines['top'].set_visible(False)
    axs[2].spines['left'].set_linewidth(3)
    axs[2].spines['bottom'].set_linewidth(3)
    axs[2].xaxis.set_tick_params(labelsize=15)
    axs[2].yaxis.set_tick_params(labelsize=15)

    axs[3].set_title(r'Macro-F1', fontsize=20)
#     axs[3].errorbar(x, f1_few_shots, linewidth=2,
#                        color="dodgerblue", marker="*", markersize=18, 
#                        capsize=2, capthick=1, ecolor='g')
#     axs[3].errorbar(x, f1_few_shots_aug, linewidth=2,
#                        color="red", marker="^", markersize=18, 
#                        capsize=2, capthick=1, ecolor='r')
#     axs[3].errorbar(x, f1_few_shots_aug_balance, linewidth=2,
#                        color="green", marker=".", markersize=18, 
#                        capsize=2, capthick=1, ecolor='y',)
    axs[3].errorbar(x, f1_few_shots_aug_large_epochs, linewidth=2,
                       color="dodgerblue", marker="*", markersize=18, 
                       capsize=2, capthick=1, ecolor='y')
    axs[3].errorbar(x, f1_approximate_large_epochs, linewidth=2,
                       color="red", ls='-.', marker="^", markersize=18, 
                       capsize=2, capthick=1, ecolor='y')
    
    axs[3].spines['right'].set_visible(False)
    axs[3].spines['top'].set_visible(False)
    axs[3].spines['left'].set_linewidth(3)
    axs[3].spines['bottom'].set_linewidth(3)
    axs[3].xaxis.set_tick_params(labelsize=15)
    axs[3].yaxis.set_tick_params(labelsize=15)

    plt.subplots_adjust(wspace=0.4, 
                        hspace=0.4)

    _ = fig.text(0.5, -0.02, r'Number of True Counterfactual Training Examples', ha='center', fontsize=22)
    plt.savefig("./figures/kshots-experiments.png",dpi=200, bbox_inches='tight')

# %% [markdown]
# interchange site size plots

# %%
data = [[0.72,0.81,0.50,0.96,0.54,0.81],
[0.71,0.81,0.51,0.87,0.52,0.81],
[0.70,0.81,0.50,0.81,0.51,0.81],
[0.69,0.81,0.49,0.79,0.50,0.80],
[0.68,0.81,0.49,0.74,0.48,0.79],
[0.68,0.80,0.48,0.70,0.47,0.76],
[0.66,0.80,0.47,0.67,0.47,0.73]]

# %%
l2_cpm = [data[i][0] for i in range(7)]
l2_control = [data[i][1] for i in range(7)]
cosine_cpm = [data[i][2] for i in range(7)]
cosine_control = [data[i][3] for i in range(7)]
normdiff_cpm = [data[i][4] for i in range(7)]
normdiff_control = [data[i][5] for i in range(7)]

# %%
plt.rcParams["font.family"] = "DejaVu Serif"
font = {'family' : 'DejaVu Serif',
        'size'   : 20}
plt.rc('font', **font)
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
x = [1,4,16,32,64,128,192]

axs[0].title.set_text(r'L2$_{\rm ICaCE}$')
axs[0].errorbar(x, l2_cpm, linewidth=2,
                   color="dodgerblue", marker="*", markersize=18, 
                   capsize=2, capthick=1, ecolor='g', label='CPM')
axs[0].errorbar(x, l2_control, linewidth=2,
                   color="red", marker="^", markersize=18, 
                   capsize=2, capthick=1, ecolor='r', label='Finetune')
axs[0].set_ylim(0.6, 0.85)
axs[0].spines['right'].set_visible(False)
axs[0].spines['top'].set_visible(False)
axs[0].spines['left'].set_linewidth(3)
axs[0].spines['bottom'].set_linewidth(3)
axs[0].legend(loc='lower left',
           ncol=1, fancybox=True, shadow=True, fontsize=20)


axs[1].title.set_text(r'COS$_{\rm ICaCE}$')
axs[1].errorbar(x, cosine_cpm, linewidth=2,
                   color="dodgerblue", marker="*", markersize=18, 
                   capsize=2, capthick=1, ecolor='g')
axs[1].errorbar(x, cosine_control, linewidth=2,
                   color="red", marker="^", markersize=18, 
                   capsize=2, capthick=1, ecolor='r')
axs[1].set_ylim(0.4, 0.98)

axs[1].spines['right'].set_visible(False)
axs[1].spines['top'].set_visible(False)
axs[1].spines['left'].set_linewidth(3)
axs[1].spines['bottom'].set_linewidth(3)

axs[2].title.set_text(r'NormDiff$_{\rm ICaCE}$')
axs[2].errorbar(x, normdiff_cpm, linewidth=2,
                   color="dodgerblue", marker="*", markersize=18, 
                   capsize=2, capthick=1, ecolor='g')
axs[2].errorbar(x, normdiff_control, linewidth=2,
                   color="red", marker="^", markersize=18, 
                   capsize=2, capthick=1, ecolor='r')
axs[2].set_ylim(0.45, 0.85)

axs[2].spines['right'].set_visible(False)
axs[2].spines['top'].set_visible(False)
axs[2].spines['left'].set_linewidth(3)
axs[2].spines['bottom'].set_linewidth(3)


plt.subplots_adjust(wspace=0.4, 
                    hspace=0.4)
fig.text(0.5, -0.03, r'Interchange Site Size (h$_{\rm c}$)', ha='center', fontsize=22)
plt.savefig("./figures/interchange-site-size.png",dpi=200, bbox_inches='tight')

# %% [markdown]
# Random plots for gradients over tokens

# %%
ambiance_df = pd.read_csv('./figures/ambiance_df.csv')
food_df = pd.read_csv('./figures/food_df.csv')
noise_df = pd.read_csv('./figures/noise_df.csv')
service_df = pd.read_csv('./figures/service_df.csv')

# %%
plt.rcParams["font.family"] = "DejaVu Serif"
font = {'family' : 'DejaVu Serif',
        'size'   : 20}
plt.rc('font', **font)

fig, axs = plt.subplots(8, 1, figsize=(8,4.5))
color_1 = "magma"
color_2 = "viridis"
_ = sns.heatmap(
    ax=axs[0],
    data=[ambiance_df[ambiance_df["model"]=="control"]["weight"]], 
    cmap=color_1, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[0].set_ylabel("amb.")

_ = sns.heatmap(
    ax=axs[1],
    data=[food_df[food_df["model"]=="control"]["weight"]], 
    cmap=color_1, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[1].set_ylabel("foo.")

_ = sns.heatmap(
    ax=axs[2],
    data=[noise_df[noise_df["model"]=="control"]["weight"]], 
    cmap=color_1, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[2].set_ylabel("noi.")

_ = sns.heatmap(
    ax=axs[3],
    data=[service_df[service_df["model"]=="control"]["weight"]], 
    cmap=color_1, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[3].set_ylabel("ser.")

_ = sns.heatmap(
    ax=axs[4],
    data=[ambiance_df[ambiance_df["model"]=="CPM"]["weight"]], 
    cmap=color_2, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[4].set_ylabel("amb.")

_ = sns.heatmap(
    ax=axs[5],
    data=[food_df[food_df["model"]=="CPM"]["weight"]], 
    cmap=color_2, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[5].set_ylabel("foo.")

_ = sns.heatmap(
    ax=axs[6],
    data=[noise_df[noise_df["model"]=="CPM"]["weight"]], 
    cmap=color_2, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[6].set_ylabel("noi.")

_ = sns.heatmap(
    ax=axs[7],
    data=[service_df[service_df["model"]=="CPM"]["weight"]], 
    cmap=color_2, 
    xticklabels=service_df[service_df["model"]=="CPM"]["word"], 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[7].set_ylabel("ser.")
_ = axs[7].set_xticklabels(axs[7].get_xmajorticklabels(), fontsize = 19)
fig.text(0.05, 0.32, 'CPM', va='center', rotation='vertical')
fig.text(0.05, 0.70, 'Fintune', va='center', rotation='vertical')
plt.savefig("./figures/gradients.png",dpi=200, bbox_inches='tight')

# %%
ambiance_df = pd.read_csv("../proxy_training_results/BERT-fewshots-augment-large-epochs-no-probe-results/ambiance_df.csv")
food_df = pd.read_csv("../proxy_training_results/BERT-fewshots-augment-large-epochs-no-probe-results/food_df.csv")
noise_df = pd.read_csv("../proxy_training_results/BERT-fewshots-augment-large-epochs-no-probe-results/noise_df.csv")
service_df = pd.read_csv("../proxy_training_results/BERT-fewshots-augment-large-epochs-no-probe-results/service_df.csv")

# %%
plt.rcParams["font.family"] = "DejaVu Serif"
font = {'family' : 'DejaVu Serif',
        'size'   : 20}
plt.rc('font', **font)

fig, axs = plt.subplots(8, 1, figsize=(8,4.5))
color_1 = "magma"
color_2 = "viridis"
_ = sns.heatmap(
    ax=axs[0],
    data=[ambiance_df[ambiance_df["model"]=="control"]["weight"]], 
    cmap=color_1, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[0].set_ylabel("amb.")

_ = sns.heatmap(
    ax=axs[1],
    data=[food_df[food_df["model"]=="control"]["weight"]], 
    cmap=color_1, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[1].set_ylabel("foo.")

_ = sns.heatmap(
    ax=axs[2],
    data=[noise_df[noise_df["model"]=="control"]["weight"]], 
    cmap=color_1, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[2].set_ylabel("noi.")

_ = sns.heatmap(
    ax=axs[3],
    data=[service_df[service_df["model"]=="control"]["weight"]], 
    cmap=color_1, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[3].set_ylabel("ser.")

_ = sns.heatmap(
    ax=axs[4],
    data=[ambiance_df[ambiance_df["model"]=="CPM"]["weight"]], 
    cmap=color_2, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[4].set_ylabel("amb.")

_ = sns.heatmap(
    ax=axs[5],
    data=[food_df[food_df["model"]=="CPM"]["weight"]], 
    cmap=color_2, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[5].set_ylabel("foo.")

_ = sns.heatmap(
    ax=axs[6],
    data=[noise_df[noise_df["model"]=="CPM"]["weight"]], 
    cmap=color_2, 
    xticklabels=False, 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[6].set_ylabel("noi.")

_ = sns.heatmap(
    ax=axs[7],
    data=[service_df[service_df["model"]=="CPM"]["weight"]], 
    cmap=color_2, 
    xticklabels=service_df[service_df["model"]=="CPM"]["word"], 
    yticklabels=False, cbar=False,
    linewidths=0.1,
)
axs[7].set_ylabel("ser.")
_ = axs[7].set_xticklabels(axs[7].get_xmajorticklabels(), fontsize = 19)
fig.text(0.05, 0.32, 'CPM', va='center', rotation='vertical')
fig.text(0.05, 0.70, 'Fintune', va='center', rotation='vertical')
# plt.savefig("./figures/gradients.png",dpi=200, bbox_inches='tight')
